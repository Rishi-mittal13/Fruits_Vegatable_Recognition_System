# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Test set Image Processing

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/Fruit_Vegetable_Recgonition/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64,64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# #Loading Model

# %%
cnn = tf.keras.models.load_model('/content/drive/MyDrive/Fruit_Vegetable_Recgonition/trained_modelF (2).h5')

# %% [markdown]
# ##Visualising and Performing Prediction on Single image

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Fruit_Vegetable_Recgonition/test/grapes/Image_6.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# #Testing Model

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 37ms/step

# %%
print(predictions)
# Out:
# [[2.24041243e-22 1.52207640e-28 3.86925565e-14 1.78145901e-26
#   0.00000000e+00 4.34789365e-24 8.69069834e-32 9.49158481e-35
#   3.31622950e-25 7.25918954e-32 5.20047106e-32 1.51627470e-14
#   1.12074750e-20 1.05106787e-26 1.00000000e+00 8.61814068e-23
#   1.85365244e-28 2.86661911e-33 2.39322421e-32 6.76267592e-38
#   2.53107738e-17 2.62685259e-29 3.47219814e-25 1.56037545e-24
#   0.00000000e+00 1.00871751e-20 1.49123183e-12 8.41118456e-30
#   9.34617868e-20 2.23170503e-28 0.00000000e+00 5.00315882e-37
#   1.46164771e-26 4.34611674e-25 1.54571661e-19 3.62000307e-25]]

# %%
test_set.class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 14

# %%
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Single image Prediction
print("It's a {}".format(test_set.class_names[result_index]))
# Out:
# It's a grapes
